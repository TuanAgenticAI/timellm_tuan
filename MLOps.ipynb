# %%
def repreat(n):
    def decorator(func):
        for _ in range(n):
            result = func(*args, **kwargs)
        return result
    return decorator

# %%
@repreat(5)
def say_hello():
    print("Hello, world!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 @repreat(5)
#       2 def say_hello():
#       3     print("Hello, world!")
#
# Cell In[13], line 4, in repreat.<locals>.decorator(func)
#       2 def decorator(func):
#       3     for _ in range(n):
# ----> 4         result = func(*args, **kwargs)
#       5     return result
#
# NameError: name 'args' is not defined

# %%
say_hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 say_hello()
#
# TypeError: 'NoneType' object is not callable

# %%
from dataclasses import dataclass

@dataclass
class Person:
    name: str
    age: int
    gender: str
